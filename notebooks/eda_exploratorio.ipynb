# %%
import pandas as pd

df_categoria = pd.read_parquet('../data/bronze/PS_Categoria.parquet')
df_cliente = pd.read_parquet('../data/bronze/PS_Cliente.parquet')
df_conta_pagamento = pd.read_parquet('../data/bronze/PS_Conta_Pagar.parquet')
df_conta_receber = pd.read_parquet('../data/bronze/PS_Conta_Receber.parquet')
df_meta = pd.read_parquet('../data/bronze/PS_Meta2025.parquet')
df_banco_central = pd.read_parquet('../data/bronze/bcb_cotacoes.parquet')

# %%
df_categoria.head()
# Out:
#   codigo_categoria                        nome_categoria tipo_categoria
# 0           1.1.01           VENDA DE PRODUTOS NACIONAIS        receita
# 1           1.1.02          VENDA DE PRODUTOS EXPORTAÇÃO        RECEITA
# 2           1.1.03       PRESTAÇÃO DE SERVIÇOS NACIONAIS        Receita
# 3           1.1.04  PRESTAÇÃO DE SERVIÇOS INTERNACIONAIS        reCeita
# 4           1.1.05                RECEITA DE ASSINATURAS        REceita

# %%
print(df_categoria.info())
print(df_categoria.value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   codigo_categoria  34 non-null     object
#  1   nome_categoria    34 non-null     object
#  2   tipo_categoria    34 non-null     object
# dtypes: object(3)
# memory usage: 972.0+ bytes
# None
# codigo_categoria  nome_categoria                            tipo_categoria
# 3.1.06            ÁGUA E SANEAMENTO                         despesa           2
# 1.1.02            VENDA DE PRODUTOS EXPORTAÇÃO              RECEITA           1
# 1.1.01            VENDA DE PRODUTOS NACIONAIS               receita           1
# 1.1.04            PRESTAÇÃO DE SERVIÇOS INTERNACIONAIS      reCeita           1
# 1.1.05            RECEITA DE ASSINATURAS                    REceita           1
# 1.1.06            RECEITA FINANCEIRA SOBRE APLICAÇÕES       receita           1
# ...

# %%
df_cliente.head()
# Out:
#    id_cliente     nome_cliente    pais_cliente data_cadastro_cliente
# 0           1       Ana Souza           BRASIL            2023-01-05
# 1           2    CARLOS MENDES       portugal             12/01/2023
# 2           3   Julien  Martin         FranÃ§a            2023-01-18
# 3           4  michael johnson  Estados Unidos            25/01/2023
# 4           5     Sophia Brown         CANADÃ            2023-02-02
